# %% [markdown]
# <a href="https://colab.research.google.com/github/adityasharma10699/demopygit/blob/main/Loans.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/content/drive/MyDrive/Data Mining/Class work/Loans.csv')

# %%
df
# Out:
#       Loan Status  Loan Amount  Credit Score  Annual Income  \
# 0      No Default       445412           709        1167493
# 1      No Default       347666           721         806949
# 2      No Default       217646           730        1184194
# 3      No Default       548746           678        2559110
# 4      No Default       234124           727         693234
# ...           ...          ...           ...            ...
# 12095  No Default       437822           742         856482
# 12096  No Default       235048           684         876204
# 12097  No Default       337502           714        1428192
# 12098  No Default       538604           622        1550552
# 12099  No Default       397100           745         857394
#
#       Years in current job Home Ownership  Monthly Debt  \
# 0                6-9 years  Home Mortgage       5214.74
# 1                2-5 years       Own Home       8741.90
# 2                <= 1 year  Home Mortgage      10855.08
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12100 entries, 0 to 12099
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Loan Status                12100 non-null  object
#  1   Loan Amount                12100 non-null  int64
#  2   Credit Score               12100 non-null  int64
#  3   Annual Income              12100 non-null  int64
#  4   Years in current job       12100 non-null  object
#  5   Home Ownership             12100 non-null  object
#  6   Monthly Debt               12100 non-null  float64
#  7   Years of Credit History    12100 non-null  float64
#  8   Number of Open Accounts    12100 non-null  int64
#  9   Number of Credit Problems  12100 non-null  int64
#  10  Bankruptcies               12100 non-null  int64
#  11  Tax Liens                  12100 non-null  int64
# dtypes: float64(2), int64(7), object(3)
# memory usage: 1.1+ MB

# %%
df.hist()
# Out:
# array([[<Axes: title={'center': 'Loan Status'}>,
#         <Axes: title={'center': 'Loan Amount'}>,
#         <Axes: title={'center': 'Credit Score'}>],
#        [<Axes: title={'center': 'Annual Income'}>,
#         <Axes: title={'center': 'Years in current job'}>,
#         <Axes: title={'center': 'Home Ownership'}>],
#        [<Axes: title={'center': 'Monthly Debt'}>,
#         <Axes: title={'center': 'Years of Credit History'}>,
#         <Axes: title={'center': 'Number of Open Accounts'}>],
#        [<Axes: title={'center': 'Number of Credit Problems'}>,
#         <Axes: title={'center': 'Bankruptcies'}>,
#         <Axes: title={'center': 'Tax Liens'}>]], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder, StandardScaler

# %%
le = LabelEncoder()

# %%
df['Loan Status'] = le.fit_transform(df['Loan Status'])
df['Years in current job'] = le.fit_transform(df['Years in current job'])
df['Home Ownership'] = le.fit_transform(df['Home Ownership'])

# %%
df
# Out:
#        Loan Status  Loan Amount  Credit Score  Annual Income  \
# 0                1       445412           709        1167493
# 1                1       347666           721         806949
# 2                1       217646           730        1184194
# 3                1       548746           678        2559110
# 4                1       234124           727         693234
# ...            ...          ...           ...            ...
# 12095            1       437822           742         856482
# 12096            1       235048           684         876204
# 12097            1       337502           714        1428192
# 12098            1       538604           622        1550552
# 12099            1       397100           745         857394
#
#        Years in current job  Home Ownership  Monthly Debt  \
# 0                         2               0       5214.74
# 1                         1               1       8741.90
# ...

# %%
X = df.drop(columns = ['Loan Status'])
Y = df['Loan Status']

# %%
from sklearn.preprocessing import StandardScaler
scaled = StandardScaler()
X_scaled = scaled.fit_transform(X)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.25, random_state=42)

# %%
from sklearn import svm
support = svm.SVC()
support.fit(X_train, Y_train)
Y_pred_SVC = support.predict(X_test)

# %%
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
print(confusion_matrix(Y_test, Y_pred_SVC))
print(classification_report(Y_test, Y_pred_SVC))
# Out:
# [[   0  775]
#  [   0 2250]]
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       775
#            1       0.74      1.00      0.85      2250
#
#     accuracy                           0.74      3025
#    macro avg       0.37      0.50      0.43      3025
# weighted avg       0.55      0.74      0.63      3025
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import make_classification
RFC = RandomForestClassifier(max_depth=2, random_state=0)
RFC.fit(X_train,Y_train)
Y_pred_RFC = RFC.predict(X_test)

# %%
print(confusion_matrix(Y_test, Y_pred_RFC))
print(classification_report(Y_test, Y_pred_RFC))
# Out:
# [[ 207  568]
#  [   0 2250]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.27      0.42       775
#            1       0.80      1.00      0.89      2250
#
#     accuracy                           0.81      3025
#    macro avg       0.90      0.63      0.65      3025
# weighted avg       0.85      0.81      0.77      3025
